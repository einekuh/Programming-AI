# %%
import numpy as np
from sklearn.datasets import fetch_california_housing
from sklearn.neighbors import KNeighborsRegressor
from sklearn.preprocessing import StandardScaler

# California Housing-Datensatz laden
california = fetch_california_housing()
X = california.data
y = california.target
print(california.feature_names)
print(california.target_names)
# k-NN Regressor initialisieren
knn_regressor = KNeighborsRegressor(n_neighbors=5)

# Normalisieren der Werte nicht vergessen!
scaler = StandardScaler()
X = scaler.fit_transform(X)

# Modell mit dem gesamten Datensatz trainieren
knn_regressor.fit(X, y)

# Beispielvorhersage für ein neues Haus
new_house = np.array([[8.5, 41.0, 6.9, 1.1, 322.0, 2.5, 37.88, -122.23]])
predicted_price = knn_regressor.predict(new_house)
print(f'Der vorhergesagte Preis für das neue Haus ist: ${predicted_price[0] * 100000:.2f}')
# Out:
# ['MedInc', 'HouseAge', 'AveRooms', 'AveBedrms', 'Population', 'AveOccup', 'Latitude', 'Longitude']
# ['MedHouseVal']
# Der vorhergesagte Preis für das neue Haus ist: $205420.00
